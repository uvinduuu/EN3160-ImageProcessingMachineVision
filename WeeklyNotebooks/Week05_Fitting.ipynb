# %% [markdown]
# # Fitting
#
# ### Least-Squares Line Fitting
#
# $$
# B = \left( X^T X \right)^{-1} X^T Y
# $$

# %%
# Least-Squares
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg

m = 2 # Line equation: y = m*x + c. m is the slope. c is the intercept.
c = 1
x = np.arange(1,10, 1)
n = 2.*np.random.randn(len(x)) # Noise
o = np.zeros(x.shape)
y = m*x + c + n + o # Noisy points confirming to a line

X = np.concatenate([x.reshape(len(x),1), np.ones((len(x), 1))], axis=1)
print(X.transpose()@X)
B = np.linalg.pinv(X.T@X)@X.T@y # Pseudo inverse computation
print(B)
mstar = B[0]
cstar = B[1]

plt.plot([x[0], x[-1]], [m*x[0] + c, m*x[-1]+c], color='k', linestyle='-', linewidth=2, label=r'Original')
plt.plot([x[0], x[-1]], [mstar*x[0] + c, mstar*x[-1]+cstar], 
         color='r', linestyle='-', linewidth=2, label=r'Estimated')
plt.plot(x,y, 'o', label='Noisy points')
plt.legend(loc='best')
# Out:
# [[285.  45.]
#  [ 45.   9.]]
# [1.61195551 2.58261267]

# %% [markdown]
# ### Effect of Outliers

# %%
# Total Least Squares

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg

m = 2
c = 1
x = np.arange(1,10, 0.5) # Un-corrupted x
# Append a number to x
x = np.append(x, 20)
n = np.random.randn(len(x))
o = np.zeros(x.shape)
o[-1] = 20 # Outliers
y = m*x + c + n + o

X = np.concatenate([x.reshape(len(x),1), np.ones((len(x), 1))], axis=1)
print(X.transpose()@X)
B = np.linalg.pinv(X.T@X)@X.T@y
print(B)
mstar = B[0]
cstar = B[1]

plt.plot([x[0], x[-1]], [m*x[0] + c, m*x[-1]+c], color='k', linestyle='-', linewidth=2, label=r'Original')
plt.plot([x[0], x[-1]], [mstar*x[0] + c, mstar*x[-1]+cstar], 
         color='r', linestyle='-', linewidth=2, label=r'Estimated')
plt.plot(x,y, 'o', label='Noisy points')
plt.legend(loc='best')
# Out:
# [[1017.25  114.5 ]
#  [ 114.5    19.  ]]
# [ 2.9266401 -3.4846857]

# %% [markdown]
# ### Total Least Square

# %%
# Generation of a Noisy Point Set Conforming to a Line and a Circle
import numpy as np
from scipy.optimize import minimize
from scipy import linalg
import matplotlib.pyplot as plt
import tikzplotlib
# np.random.seed(0)
N = 100
t = np.random.uniform(0, 2*np.pi, N)

s = 1.
m, c = -1, 2
x = np.linspace(-12, 12, N) 
y = m*x + c + s*np.random.randn(N)
X_line = np.hstack((x.reshape(N,1), y.reshape(N,1))) 

fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.scatter(X_line[:,0],X_line[:,1], label='Line')
x_min, x_max = ax.get_xlim()
x_ = np.array([x_min, x_max])
y_ = m*x_ + c
plt.plot(x_, y_, color='m', label='Ground truth line')
plt.legend()

# %% [markdown]
# $$
# d = a\bar{x} + b\bar{y}
# $$
#
# $$
# \left\| \begin{bmatrix}
# x_1 - \bar{x} & y_1 - \bar{y} \\
# x_2 - \bar{x} & y_2 - \bar{y} \\
# \vdots & \vdots \\
# x_n - \bar{x} & y_n - \bar{y}
# \end{bmatrix}
# \begin{pmatrix}
# a \\
# b
# \end{pmatrix} \right\|^2 = \|UN\|^2
# $$
#
# $$
# \text{Minimize } \|UN\|^2 \text{ subject to } \|N\|^2 = 1
# $$

# %%
# Item 2: Line fitting with Total Least Squares
import math
N = X_line.shape[0]
X_ = X_line


U = X_ - np.mean(X_, axis=0)

# Eigenvector of 𝑈^𝑇𝑈 associated with the smallest eigenvalue
_, _, Vt = np.linalg.svd(np.transpose(U)@U)
a, b = Vt[-1, 0], Vt[-1, 1]
d = a*np.mean(X_[:,0]) + b*np.mean(X_[:,1])
best_model_line = np.array([a, b, d])

print('Best line model', best_model_line)

fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.scatter(X_line[:,0],X_line[:,1], label='All points')
x_min, x_max = ax.get_xlim()
x_ = np.array([x_min, x_max])
y_ = (-best_model_line[1]*x_ + best_model_line[2])/best_model_line[1]
plt.plot(x_, y_, label='Total least squares line')
y_ = m*x_ + c
plt.plot(x_, y_, label='Ground truth line')
plt.legend()
# Out:
# Best line model [0.71124437 0.70294484 1.36702461]

# %% [markdown]
# ### Total least squares line fitting with scicpy.optimize with RANSAC

# %%
# Item 2: Total least squares line fitting with scicpy.optimize with RANSAC
import math
N = X_line.shape[0]
X_ = X_line

def line_equation_from_points(x1, y1, x2, y2):
    # Calculate the direction vector (Δx, Δy)
    delta_x = x2 - x1
    delta_y = y2 - y1

    # Calculate the normalized vector (a, b)
    magnitude = math.sqrt(delta_x**2 + delta_y**2)
    a = delta_y / magnitude
    b = -delta_x / magnitude

    # Calculate d
    d = (a * x1) + (b * y1)

    # Return the line equation in the form ax + by = d
    return a, b, d

# RANSAC to fit a line
def line_tls(x, indices):
    a, b, d = x[0], x[1], x[2]
    return np.sum(np.square(a*X_[indices,0] + b*X_[indices,1] - d))

# Constraint
def g(x):
    return x[0]**2 + x[1]**2 - 1

cons = ({'type': 'eq', 'fun': g})

# Computing the consensus (inliers)
def consensus_line(X, x, t):
    a, b, d = x[0], x[1], x[2]
    error = np.absolute(a*X_[:,0] + b*X_[:,1] - d)
    return error < t

t = 1.   # Threshold value to determine data points that are fit well by model.
d = 0.4*N   # Number of close data points required to assert that a model fits well to data.
s = 2       # Minimum number of data points required to estimate model parameters.

inliers_line = []        # Indinces of the inliers
max_iterations = 50
iteration = 0
best_model_line = []     # Best model normal (a, b) and distance from origin d
best_error = np.inf
best_sample_line = []    # Three-point sample leading to the best model computation
res_only_with_sample = [] # Result (a, b, d) only using the best sample
best_inliers_line = []   # Inliers of the model computed form the best sample

while iteration < max_iterations:   
    indices = np.random.randint(0, N, s) # A sample of three (s) points selected at random
    x0 = np.array([1, 1, 0]) # Initial estimate
    res = minimize(fun = line_tls, args = indices, x0 = x0, tol= 1e-6, constraints=cons, options={'disp': True})
    inliers_line = consensus_line(X_, res.x, t) # Computing the inliers
    print('rex.x: ', res.x)    
    print('Iteration = ', iteration, '. No. inliners = ', inliers_line.sum())
    if inliers_line.sum() > d:
        x0 = res.x
        # Computing the new model using the inliers
        res = minimize(fun = line_tls, args = inliers_line, x0 = x0, tol= 1e-6, constraints=cons, options={'disp': True})
        print(res.x, res.fun)
        if res.fun < best_error:
            print('A better model found ... ', res.x, res.fun)
            best_model_line = res.x
            best_eror = res.fun
            best_sample_line = X_[indices,:]
            res_only_with_sample = x0
            best_inliers_line = inliers_line

    iteration += 1

print('Best line model', best_model_line)

fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.scatter(X_line[:,0],X_line[:,1], label='All points')
ax.scatter(X_[best_inliers_line,0],X_[best_inliers_line,1], color='y', label='Inliers')
ax.scatter(best_sample_line[:,0],best_sample_line[:,1], color='r', label='Best sample')
x_min, x_max = ax.get_xlim()
x_ = np.array([x_min, x_max])
y_ = (-best_model_line[1]*x_ + best_model_line[2])/best_model_line[1]
plt.plot(x_, y_,  label='RANSAC line')
x_ = np.array([x_min, x_max])
y_ = m*x_ + b
plt.plot(x_, y_, color='m', label='Ground truth line')
plt.legend()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9279011413683245e-08
#             Iterations: 7
#             Function evaluations: 32
#             Gradient evaluations: 7
# rex.x:  [0.69703402 0.71703807 2.24904181]
# Iteration =  0 . No. inliners =  55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.868619099046721
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# [0.69950591 0.71462683 1.88304106] 5.868619099046721
# A better model found ...  [0.69950591 0.71462683 1.88304106] 5.868619099046721
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.231570133905819e-10
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.76602379 0.64281223 2.28360359]
# Iteration =  1 . No. inliners =  44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.598935772395262
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.75160335 0.65961535 2.00667991] 8.598935772395262
# A better model found ...  [0.75160335 0.65961535 2.00667991] 8.598935772395262
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.946275258058628e-10
#             Iterations: 6
#             Function evaluations: 27
#             Gradient evaluations: 6
# rex.x:  [0.62988812 0.77668592 0.72217695]
# Iteration =  2 . No. inliners =  46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 11.216302065026447
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.66026102 0.75103621 0.99709989] 11.216302065026447
# A better model found ...  [0.66026102 0.75103621 0.99709989] 11.216302065026447
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.554566209325729e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.73145799 0.68188695 0.96964932]
# Iteration =  3 . No. inliners =  79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 19.812540763443106
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.72120713 0.69271948 1.1905949 ] 19.812540763443106
# A better model found ...  [0.72120713 0.69271948 1.1905949 ] 19.812540763443106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.640445263563837e-08
#             Iterations: 7
#             Function evaluations: 31
#             Gradient evaluations: 7
# rex.x:  [0.64344799 0.76548984 2.66465232]
# Iteration =  4 . No. inliners =  45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.732989870846527
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.67531215 0.73753203 2.11342885] 8.732989870846527
# A better model found ...  [0.67531215 0.73753203 2.11342885] 8.732989870846527
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.397551679607759e-10
#             Iterations: 5
#             Function evaluations: 24
#             Gradient evaluations: 5
# rex.x:  [0.60584422 0.79558334 3.72236322]
# Iteration =  5 . No. inliners =  28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0479310080216293e-08
#             Iterations: 6
#             Function evaluations: 27
#             Gradient evaluations: 6
# rex.x:  [0.74093967 0.67157163 2.43297103]
# Iteration =  6 . No. inliners =  45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.248958219432314
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.73024978 0.68318026 1.94981956] 8.248958219432314
# A better model found ...  [0.73024978 0.68318026 1.94981956] 8.248958219432314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2915814121243656e-09
#             Iterations: 6
#             Function evaluations: 29
#             Gradient evaluations: 6
# rex.x:  [0.68685839 0.72679127 1.29198788]
# Iteration =  7 . No. inliners =  81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 21.362607064525424
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.70086761 0.71329138 1.39695378] 21.362607064525424
# A better model found ...  [0.70086761 0.71329138 1.39695378] 21.362607064525424
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2469864525271746e-11
#             Iterations: 7
#             Function evaluations: 32
#             Gradient evaluations: 7
# rex.x:  [0.8311067  0.55611299 3.13909136]
# Iteration =  8 . No. inliners =  34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.7343594534132934e-10
#             Iterations: 6
#             Function evaluations: 29
#             Gradient evaluations: 6
# rex.x:  [0.72767944 0.68591737 1.36845959]
# Iteration =  9 . No. inliners =  82
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 19.142333523643277
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.72160807 0.69230181 1.40202603] 19.142333523643277
# A better model found ...  [0.72160807 0.69230181 1.40202603] 19.142333523643277
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.37691387006471e-09
#             Iterations: 7
#             Function evaluations: 31
#             Gradient evaluations: 7
# rex.x:  [0.79623798 0.60498353 2.78983118]
# Iteration =  10 . No. inliners =  34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3344572418526322e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.76490475 0.64414383 1.27700037]
# Iteration =  11 . No. inliners =  62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 10.904174243835039
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.73808466 0.67470811 1.34780624] 10.904174243835039
# A better model found ...  [0.73808466 0.67470811 1.34780624] 10.904174243835039
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.223682482233341e-10
#             Iterations: 6
#             Function evaluations: 26
#             Gradient evaluations: 6
# rex.x:  [0.66286056 0.74874336 1.38801209]
# Iteration =  12 . No. inliners =  65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 15.592701650273577
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.68132007 0.73198563 1.4570624 ] 15.592701650273577
# A better model found ...  [0.68132007 0.73198563 1.4570624 ] 15.592701650273577
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3133035676856412e-08
#             Iterations: 9
#             Function evaluations: 39
#             Gradient evaluations: 9
# rex.x:  [ 0.96172262  0.2740249  -4.90440069]
# Iteration =  13 . No. inliners =  10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.780305087873072e-09
#             Iterations: 7
#             Function evaluations: 31
#             Gradient evaluations: 7
# rex.x:  [0.7457742  0.66619891 2.5914903 ]
# Iteration =  14 . No. inliners =  39
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.145370123185452e-10
#             Iterations: 6
#             Function evaluations: 29
#             Gradient evaluations: 6
# rex.x:  [0.68454382 0.72897172 2.12078403]
# Iteration =  15 . No. inliners =  65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 11.887239163018887
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.6940598  0.71991739 1.7859521 ] 11.887239163018887
# A better model found ...  [0.6940598  0.71991739 1.7859521 ] 11.887239163018887
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.318891903935136e-12
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.68432851 0.72917384 2.21802686]
# Iteration =  16 . No. inliners =  59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.361370950668316
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.69585153 0.71818568 1.8483971 ] 8.361370950668316
# A better model found ...  [0.69585153 0.71818568 1.8483971 ] 8.361370950668316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6303587404208404e-10
#             Iterations: 5
#             Function evaluations: 24
#             Gradient evaluations: 5
# rex.x:  [0.72202408 0.69186793 1.95147663]
# Iteration =  17 . No. inliners =  70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 12.012581401445932
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.71590719 0.69819546 1.68160457] 12.012581401445932
# A better model found ...  [0.71590719 0.69819546 1.68160457] 12.012581401445932
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5415921115374723e-09
#             Iterations: 13
#             Function evaluations: 56
#             Gradient evaluations: 13
# rex.x:  [ -0.23605861   0.97173901 -12.12977154]
# Iteration =  18 . No. inliners =  6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.0091412216729907e-12
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.5545845  0.83212741 3.54641122]
# Iteration =  19 . No. inliners =  28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.318891903935136e-12
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.68432851 0.72917384 2.21802686]
# Iteration =  20 . No. inliners =  59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.361370950668316
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.69585153 0.71818568 1.8483971 ] 8.361370950668316
# A better model found ...  [0.69585153 0.71818568 1.8483971 ] 8.361370950668316
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.842963872293329e-08
#             Iterations: 6
#             Function evaluations: 26
#             Gradient evaluations: 6
# rex.x:  [0.50639512 0.86230163 0.47782653]
# Iteration =  21 . No. inliners =  21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.298514270619836e-09
#             Iterations: 12
#             Function evaluations: 52
#             Gradient evaluations: 12
# rex.x:  [ -0.41871424   0.90811816 -11.28735564]
# Iteration =  22 . No. inliners =  6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.869784127215019e-08
#             Iterations: 6
#             Function evaluations: 26
#             Gradient evaluations: 6
# rex.x:  [0.82095709 0.57099018 0.69610982]
# Iteration =  23 . No. inliners =  35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9902204643884137e-07
#             Iterations: 7
#             Function evaluations: 31
#             Gradient evaluations: 7
# rex.x:  [0.68977169 0.72402694 1.18260415]
# Iteration =  24 . No. inliners =  75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 15.45360110452967
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.70533931 0.70886985 1.31550929] 15.45360110452967
# A better model found ...  [0.70533931 0.70886985 1.31550929] 15.45360110452967
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.810218297341439e-09
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.62354665 0.78178615 2.68907348]
# Iteration =  25 . No. inliners =  40
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.294508407963871e-10
#             Iterations: 6
#             Function evaluations: 29
#             Gradient evaluations: 6
# rex.x:  [0.71825306 0.69578196 1.4130424 ]
# Iteration =  26 . No. inliners =  84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 19.660316944775992
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.71552204 0.69859016 1.44189678] 19.660316944775992
# A better model found ...  [0.71552204 0.69859016 1.44189678] 19.660316944775992
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.033185673714193e-10
#             Iterations: 6
#             Function evaluations: 29
#             Gradient evaluations: 6
# rex.x:  [0.6927386  0.72118876 1.18221839]
# Iteration =  27 . No. inliners =  75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 15.4536010625253
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.7053393  0.70886986 1.31550952] 15.4536010625253
# A better model found ...  [0.7053393  0.70886986 1.31550952] 15.4536010625253
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.934246396705422e-09
#             Iterations: 6
#             Function evaluations: 29
#             Gradient evaluations: 6
# rex.x:  [0.71569002 0.69841807 0.58711464]
# Iteration =  28 . No. inliners =  60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 13.177750051282823
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.71459721 0.69953615 0.95668798] 13.177750051282823
# A better model found ...  [0.71459721 0.69953615 0.95668798] 13.177750051282823
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.246637448833225e-10
#             Iterations: 5
#             Function evaluations: 24
#             Gradient evaluations: 5
# rex.x:  [0.71106084 0.70313048 1.73555571]
# Iteration =  29 . No. inliners =  79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 16.461228739184115
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.71159943 0.70258541 1.60204666] 16.461228739184115
# A better model found ...  [0.71159943 0.70258541 1.60204666] 16.461228739184115
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4587010982176886e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.65115944 0.75894143 1.79738748]
# Iteration =  30 . No. inliners =  64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 12.79543520902159
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.68282464 0.7305823  1.6547371 ] 12.79543520902159
# A better model found ...  [0.68282464 0.7305823  1.6547371 ] 12.79543520902159
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7783391303378693e-07
#             Iterations: 6
#             Function evaluations: 27
#             Gradient evaluations: 6
# rex.x:  [0.71541466 0.69870013 1.42241814]
# Iteration =  31 . No. inliners =  85
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 20.588238270086347
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.71445515 0.69968124 1.43321318] 20.588238270086347
# A better model found ...  [0.71445515 0.69968124 1.43321318] 20.588238270086347
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3446596982199304e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.6883038  0.72542284 1.55677789]
# Iteration =  32 . No. inliners =  86
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 23.142616918580238
#             Iterations: 6
#             Function evaluations: 30
#             Gradient evaluations: 6
# [0.70429132 0.70991107 1.51717649] 23.142616918580238
# A better model found ...  [0.70429132 0.70991107 1.51717649] 23.142616918580238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.078976551922855e-09
#             Iterations: 8
#             Function evaluations: 35
#             Gradient evaluations: 8
# rex.x:  [ 0.89980425  0.43629399 -0.8719526 ]
# Iteration =  33 . No. inliners =  19
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.92918313472965e-08
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.67400883 0.73872363 1.74936687]
# Iteration =  34 . No. inliners =  73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 16.180951299173064
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.69207021 0.72183019 1.62447917] 16.180951299173064
# A better model found ...  [0.69207021 0.72183019 1.62447917] 16.180951299173064
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4223271743306646e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.67554724 0.73731702 1.49779626]
# Iteration =  35 . No. inliners =  73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 16.897890846336548
#             Iterations: 5
#             Function evaluations: 27
#             Gradient evaluations: 5
# [0.69194101 0.72195405 1.51273502] 16.897890846336548
# A better model found ...  [0.69194101 0.72195405 1.51273502] 16.897890846336548
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.106188367101661e-09
#             Iterations: 5
#             Function evaluations: 25
#             Gradient evaluations: 5
# rex.x:  [0.71024258 0.70395752 0.5163052 ]
# Iteration =  36 . No. inliners =  55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 12.476116529693465
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.70903484 0.70517345 0.87467067] 12.476116529693465
# A better model found ...  [0.70903484 0.70517345 0.87467067] 12.476116529693465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1065020270457607e-10
#             Iterations: 6
#             Function evaluations: 27
#             Gradient evaluations: 6
# rex.x:  [0.64577737 0.7635258  0.79042345]
# Iteration =  37 . No. inliners =  52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 14.52573727653872
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.67207013 0.7404875  1.03157473] 14.52573727653872
# A better model found ...  [0.67207013 0.7404875  1.03157473] 14.52573727653872
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.6287064063307223e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.73863545 0.67410555 1.53953639]
# Iteration =  38 . No. inliners =  78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 16.845884178070328
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.72500895 0.68873946 1.48052672] 16.845884178070328
# A better model found ...  [0.72500895 0.68873946 1.48052672] 16.845884178070328
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2783496693466184e-08
#             Iterations: 7
#             Function evaluations: 31
#             Gradient evaluations: 7
# rex.x:  [0.68056252 0.73269067 2.50172319]
# Iteration =  39 . No. inliners =  47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.687323455912559
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.69150673 0.72237001 2.04715369] 5.687323455912559
# A better model found ...  [0.69150673 0.72237001 2.04715369] 5.687323455912559
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.192010386888929e-15
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.71923919 0.69476254 1.33791383]
# Iteration =  40 . No. inliners =  84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 19.792312098210942
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.71482091 0.69930756 1.42166875] 19.792312098210942
# A better model found ...  [0.71482091 0.69930756 1.42166875] 19.792312098210942
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.631660845075944e-12
#             Iterations: 5
#             Function evaluations: 24
#             Gradient evaluations: 5
# rex.x:  [0.70916954 0.70503799 1.05464583]
# Iteration =  41 . No. inliners =  81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 20.188845787146644
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.71231211 0.70186285 1.28543924] 20.188845787146644
# A better model found ...  [0.71231211 0.70186285 1.28543924] 20.188845787146644
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.070726140177545e-12
#             Iterations: 6
#             Function evaluations: 29
#             Gradient evaluations: 6
# rex.x:  [0.705842   0.7083693  2.11119714]
# Iteration =  42 . No. inliners =  63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.823280616688146
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.70833874 0.70587268 1.76462868] 8.823280616688146
# A better model found ...  [0.70833874 0.70587268 1.76462868] 8.823280616688146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.3660844643164223e-12
#             Iterations: 5
#             Function evaluations: 24
#             Gradient evaluations: 5
# rex.x:  [0.73501392 0.67805202 0.88114368]
# Iteration =  43 . No. inliners =  75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 18.104781902298875
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.72301999 0.69082711 1.14963665] 18.104781902298875
# A better model found ...  [0.72301999 0.69082711 1.14963665] 18.104781902298875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.99019589113246e-08
#             Iterations: 5
#             Function evaluations: 25
#             Gradient evaluations: 5
# rex.x:  [0.76480448 0.64426255 0.864561  ]
# Iteration =  44 . No. inliners =  59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 13.261445635160669
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.74372338 0.66848749 1.03993596] 13.261445635160669
# A better model found ...  [0.74372338 0.66848749 1.03993596] 13.261445635160669
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0287078378039523e-08
#             Iterations: 6
#             Function evaluations: 27
#             Gradient evaluations: 6
# rex.x:  [0.75804676 0.65220026 0.81488879]
# Iteration =  45 . No. inliners =  62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 14.437794690091627
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.73967307 0.67296638 1.02255496] 14.437794690091627
# A better model found ...  [0.73967307 0.67296638 1.02255496] 14.437794690091627
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.1716872213536823e-07
#             Iterations: 7
#             Function evaluations: 30
#             Gradient evaluations: 7
# rex.x:  [0.62799114 0.77822052 0.87230748]
# Iteration =  46 . No. inliners =  43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.303640628111982
#             Iterations: 4
#             Function evaluations: 23
#             Gradient evaluations: 4
# [0.65075569 0.75928719 1.09148751] 8.303640628111982
# A better model found ...  [0.65075569 0.75928719 1.09148751] 8.303640628111982
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2226681692341455e-07
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [0.73538271 0.67765252 1.63341299]
# Iteration =  47 . No. inliners =  77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 15.179665683294985
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# [0.72172369 0.69218128 1.52461732] 15.179665683294985
# A better model found ...  [0.72172369 0.69218128 1.52461732] 15.179665683294985
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.691685419664776e-07
#             Iterations: 8
#             Function evaluations: 35
#             Gradient evaluations: 8
# rex.x:  [ 0.94063399  0.33942319 -5.0851002 ]
# Iteration =  48 . No. inliners =  15
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.350545418070822e-14
#             Iterations: 6
#             Function evaluations: 28
#             Gradient evaluations: 6
# rex.x:  [ 0.57235396  0.82000667 -1.47075506]
# Iteration =  49 . No. inliners =  17
# Best line model [0.72172369 0.69218128 1.52461732]

# %% [markdown]
# ## RANSAC

# %%
# RANSAC

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg

m = 2
c = 1
xo = np.arange(1,11, 0.1) # Un-corrupted x
mu, sigma = 0, 5 # mean and standard deviation
#x = xo + np.random.normal(mu, sigma, len(xo)) # noisy x
x = xo
n = np.random.normal(mu, sigma, len(xo))
o = np.zeros(x.shape)
o[-1] = 20 # Outliers
y = m*x + c + n + o

def line(x,y):
    m = (y[1] - y[0])/(x[1] - x[0])
    b = y[0] - m*x[0]
    print("m, b:", m, b)
    return m, -1, b

def distance(parameters, x, y):
    a = parameters[0]
    b = parameters[1]
    d = parameters[2]
    return (a*x + b*y - d)**2


thresh = 10
s = 2
loop = True 
consensus = []
while loop:
    samples = np.random.choice(len(x), 2, replace=False)
    print("Samples", samples)
    xs = x[samples]
    ys = y[samples]
    print(xs,ys)
    parameters = line(xs,ys)
    print(distance(parameters, x, y) )
    consensus =  distance(parameters, x, y) < thresh
    print('Consensus: ', consensus)
    print("Lenght:", sum(consensus))
    if sum(consensus) >= 2:
        loop = False
    

xc = x[consensus]
yc = y[consensus]
print("xc:", xc)
print("yc", yc)
X = np.concatenate([xc.reshape(len(xc),1), np.ones((len(xc), 1))], axis=1)
print(X.transpose()@X)
B = np.linalg.pinv(X.T@X)@X.T@yc
print(B)
mstar = B[0]
cstar = B[1]

plt.plot([x[0], x[-1]], [m*x[0] + c, m*x[-1]+c], color='k', linestyle='-', linewidth=2, label=r'Original')
plt.plot([x[0], x[-1]], [mstar*x[0] + c, mstar*x[-1]+cstar], 
         color='r', linestyle='-', linewidth=2, label=r'Estimated')
plt.plot(x,y, 'o', label='Noisy points')
plt.plot(xc, yc, '+', color='r')
plt.legend(loc='best')
# Out:
# Samples [76 94]
# [ 8.6 10.4] [20.73629726 19.0954603 ]
# m, b: -0.9115760918286149 28.575851652329305
# [1133.4693759   503.8684277   600.0316124   942.29873549 1133.97038614
#  1324.86283193  925.01954265  934.1509098   846.40117991  939.43256293
#  1155.00574516 1150.94841635 1182.72333902 1656.39374551 1411.82128712
#   774.86883211 1371.96011883 1496.20419501 1604.82597857 1201.49900645
#  1918.66855768 1644.49240362 1518.53188945 1399.81615081 1694.05571852
#  1550.00969104  825.41475332 1904.0538925  1975.77815676 2728.16074092
#  1758.88173736 1595.28061257 1307.06055675 1385.59191137 1569.01274847
#  1784.12626936 1649.0672072  1822.07397125 1488.17368413 1616.20216469
#  1257.84331701 1257.28253099 2994.07192312 1629.87331279 2241.48407349
#  2782.38012629 2065.39979254 2176.91652005 1997.79590306 2222.33284937
#  2634.95096323 1821.13614984 1983.86661474 1350.64080381 2484.52935499
#  1540.08993754 2478.57752697 2719.5383076  1861.30285164 2346.15449177
#  1833.78411292 3296.4416511  3020.68630188 3169.86216121 2112.93438951
#  3474.94569319 2153.9939227  2441.28377543 2306.76802139 3230.09894935
#  3555.26443658 2448.03627077 3065.17085573 2332.22693178 2547.2582326
#  3158.5948945  3266.31719062 3255.94411503 3568.97925856 2492.74627238
#  2721.09901559 3906.64531238 3214.66258757 4693.75462505 3310.74855108
#  3555.17871068 2919.6893537  4137.49331966 3904.79981361 3494.30199453
#  3599.86450557 4241.56446689 3632.75651145 3203.90525517 3266.31719062
#  3213.69100053 3985.89445563 4134.02747878 4038.26344006 7645.00343913]
# Consensus:  [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False]
# Lenght: 0
# Samples [40  9]
# [5.  1.9] [2.33235475 0.34231793]
# m, b: 0.6419473596555154 -0.8773820519414715
# [7.07708850e+00 7.59528934e+01 4.65385808e+01 6.02066444e-01
#  4.18738560e+00 2.12995760e+01 2.32482383e+00 2.34194398e+00
#  9.96413092e+00 3.07919706e+00 2.03089534e+00 1.46409448e+00
#  2.30966944e+00 5.88669471e+01 1.92942356e+01 3.02563414e+01
#  1.25853617e+01 2.53316101e+01 3.91523008e+01 4.95889161e-01
#  9.38729417e+01 3.94784153e+01 2.06464452e+01 8.03300653e+00
#  4.12638535e+01 2.00667863e+01 3.98904144e+01 7.11356541e+01
#  8.26845286e+01 2.79552482e+02 3.93341774e+01 1.69602651e+01
#  3.07161636e-02 1.18843837e+00 1.10358745e+01 3.35800508e+01
#  1.60742213e+01 3.51763397e+01 2.77791550e+00 9.83774709e+00
#  3.07919706e+00 3.67881329e+00 2.95377764e+02 7.20805170e+00
#  9.02890248e+01 2.17581930e+02 5.31981287e+01 6.97078150e+01
#  3.88507936e+01 7.26347683e+01 1.57688270e+02 1.40253625e+01
#  2.97629001e+01 6.19694361e+00 1.09187237e+02 9.43451183e-02
#  1.01582731e+02 1.50979018e+02 9.76953828e+00 6.83031739e+01
#  6.22406552e+00 2.86672186e+02 2.05124497e+02 2.40484853e+02
#  2.51738896e+01 3.18408707e+02 2.65341211e+01 6.39037928e+01
#  4.17071625e+01 2.28248355e+02 3.14871430e+02 5.53664033e+01
#  1.73497874e+02 3.53508384e+01 6.34816801e+01 1.83418131e+02
#  2.05583059e+02 1.98584268e+02 2.76114535e+02 4.41934790e+01
#  7.61991027e+01 3.57696474e+02 1.67763244e+02 6.05651115e+02
#  1.81784558e+02 2.37579462e+02 9.34526493e+01 3.92077167e+02
#  3.17218680e+02 2.03904275e+02 2.25312188e+02 3.99339224e+02
#  2.24196116e+02 1.24289601e+02 1.33213741e+02 1.19338056e+02
#  2.96299704e+02 3.31985479e+02 2.99845425e+02 1.68502623e+03]
# Consensus:  [ True False False  True  True False  True  True  True  True  True  True
#   True False False False False False False  True False False False  True
#  False False False False False False False False  True  True False False
#  False False  True  True  True  True False  True False False False False
#  False False False False False  True False  True False False  True False
#   True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False]
# Lenght: 23
# xc: [1.  1.3 1.4 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.9 3.3 4.2 4.3 4.8 4.9 5.  5.1
#  5.3 6.3 6.5 6.8 7. ]
# yc [ 4.17960919  0.93598421  3.8224186   0.37976053  0.43835143 -1.12371387
#   0.34231793  3.58637162  3.43546922  3.80942591  3.44322337  5.83006424
#   3.74882124  4.7279109   5.62543736  7.15944242  2.33235475  2.23329031
#   6.96448456  2.43228431  4.74288339  8.36825016  7.86582128]
# [[388.96  83.4 ]
#  [ 83.4   23.  ]]
# [0.80566697 0.78641902]

# %% [markdown]
# ## Hough Lines

# %%
# Hough Lines
import cv2 as cv
import numpy as np
img = cv.imread('Images-20240703\sigiriya.jpg')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray,50,100,apertureSize = 3)
lines = cv.HoughLines(edges,1,np.pi/180,200)

# Plotting
for line in lines:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv.line(img,(x1,y1),(x2,y2),(0,0,255),2)

    
cv.namedWindow("Image", cv.WINDOW_NORMAL)
cv.imshow("Image", img)
cv.waitKey()
cv.imshow("Image", edges)
cv.waitKey()
cv.destroyAllWindows()

# %% [markdown]
# ## Hough Circles

# %%
# Hough Circles
import cv2 as cv
import numpy as np

img = cv.imread('coins\coins.png',0)
cv.imshow('Detected Circles', img)  
cv.waitKey(0)
img = cv.medianBlur(img,7)
img = cv.GaussianBlur(img, (7,7), 3)
cimg = cv.cvtColor(img,cv.COLOR_GRAY2BGR)

circles = cv.HoughCircles(img, cv.HOUGH_GRADIENT,1,40, param1=50,param2=30,minRadius=20,maxRadius=50)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

# Display the results

cv.imshow('Detected Circles', cimg)  # Change this to display the image with circles
cv.waitKey(0)
cv.destroyAllWindows()  # Close all OpenCV windows

# %% [markdown]
# ## Generalized Hough Transform

# %%
# Generalized Hough Transform

import cv2 as cv
import numpy as np
im = cv.imread('coins\coins.png', cv.IMREAD_REDUCED_GRAYSCALE_2)
templ  = cv.imread('coins\penny.png', cv.IMREAD_REDUCED_GRAYSCALE_2)

# Canny edge detection
im_edges = cv.Canny(im, 50, 250)
templ_edges = cv.Canny(templ, 50, 250)

alg = cv.createGeneralizedHoughGuil()
alg.setTemplate(templ_edges)

# Canny thresholds not reuired as 
# alg.setCannyLowThresh(50)
# alg.setCannyHighThresh(250)

# Votes thresholds (to be carefully selected)
alg.setAngleThresh(100000)
alg.setScaleThresh(40000)
alg.setPosThresh(1000)

# alg.setAngleThresh(400000)
# alg.setScaleThresh(10000)
# alg.setPosThresh(100)

alg.setAngleStep(1)
alg.setScaleStep(0.1)
alg.setMinScale(0.9)       
alg.setMaxScale(1.1)

positions, votes = alg.detect(im_edges) # Actual detection

out = cv.cvtColor(im, cv.COLOR_BAYER_BG2BGR)
for x, y, scale, orientation in positions[0]:
    halfHeight = templ.shape[0] / 2. * scale
    halfWidth = templ.shape[1]/ 2. * scale
    p1 = (int(x - halfWidth), int(y - halfHeight))
    p2 = (int(x + halfWidth), int(y + halfHeight))
    print("x = {}, y = {}, scale = {}, orientation = {}, p1 = {}, p2 = {}".format(x, y, scale, orientation, p1, p2))
    cv.rectangle(out, p1, p2, (0,0,255))

cv.namedWindow('Image')
cv.imshow('Image', templ)
cv.waitKey(0)
cv.imshow('Image', im)
cv.waitKey(0)
cv.imshow('Image', out)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# x = 1520.0, y = 154.0, scale = 1.100000023841858, orientation = 180.0, p1 = (1437, 71), p2 = (1602, 236)

# %%
votes
# Out:
# array([[[    1025,   341559, 12705155]]], dtype=int32)
